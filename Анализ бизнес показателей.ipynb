# %% [markdown]
# ## **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут Кузьмич Валентин, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это не уместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩
# - очень красиво оформлен проект
# - здорово сделана предобработка данных
# - качественно исследованы данные
# - построено много интересных графиков
# - сделано много верных промежуточных выводов, основанных на полученных данных
#
# Твоего внимания требует:
# - расчет среднего САС
# - фильтрация органических пользователей
# - небольшое исправление графиков
# - пересмотр выводов
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, по теме проекта:
# - [Когортный анализ. Метрики продукта vs метрики роста](https://gopractice.ru/product/cohort_analysis/)
# - [Customer Lifetime Value](https://www.datacamp.com/tutorial/customer-life-time-value)
# - [Customer Lifetime Value Prediction](https://towardsdatascience.com/data-driven-growth-with-python-part-3-customer-lifetime-value-prediction-6017802f2e0f)
# - [Calculating customer lifetime value: A Python solution](https://medium.com/data-science-at-microsoft/calculating-customer-lifetime-value-a-python-solution-85aa55754b33)
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Напиши здесь свои мысли и идеи по поводу комментария ревьюера.
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v2**
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Молодец, исправлено:
# - расчет среднего САС
# - фильтрация органических пользователей
# - небольшое исправление графиков
# - пересмотр выводов
#
# Спасибо тебе за твой труд! Я готов принять работу. Успехов в дальнейшем обучении!
#
# </div>

# %% [markdown]
# ### Инструкция по выполнению проекта:
#
# Вы - маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев ваш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Вам нужно разобраться в причинах этой ситуации.
#
# У вас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Вам предстоит изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# #### Шаг 1. Загрузите данные и подготовьте их к анализу
# Загрузите данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv. Скачать датасет
#  -   /datasets/orders_info_short.csv. Скачать датасет
#  -   /datasets/costs_info_short.csv. Скачать датасет
#
# #### Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# #### Шаг 3. Проведите исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?.
#
# #### Шаг 4. Маркетинг
# Выясните:
#
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?
#
# #### Шаг 5. Оцените окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.
#
# Подумайте, нужно ли включать в анализ органических пользователей?
#
# #### Шаг 6. Напишите выводы
# - Выделите причины неэффективности привлечения пользователей;
# - Сформируйте рекомендации для отдела маркетинга для повышения эффективности.
#
# #### Оформление:
# Задание выполните в Jupyter Notebook. Программный код заполните в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
#
# #### Описание данных
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, что есть оглавление в плагине toc. Теперь по проекту удобно перемещаться.
#
# Здорово, что во вступлении к твоему проекту есть
#
# - краткое описание проекта,
#
# - описание данных,
#
# - план работы,
#
# - цель проекта
#
# Вступление станет лучше, если ты добавишь в него:
#
# - заголовок
#
# Тогда получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# ## Загрузите данные и подготовьте их к анализу
# Загрузите данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv.
#  -   /datasets/orders_info_short.csv.
#  -   /datasets/costs_info_short.csv.

# %%
#импорт библиотек
import pandas as pd
from datetime import datetime, timedelta
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, что загружаешь все библиотеки в начале проекта. Так сложней случайно удалить ячейку с загрузкой нужной библиотеки и сделать код не работающим. А получатель отчета сразу поймет, какие библиотеки ты используешь и какие ему нужно установить для запуска проекта.
#
# </div>

# %%
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),
    pd.read_csv('/datasets/orders_info_short.csv'),
    pd.read_csv('/datasets/costs_info_short.csv')
)

# %%
display(visits.head(), orders.head(), costs.head())
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %%
print('Инофрмация по таблице visits:')
visits.info()
print('------------------------------')
print('\n')
print('Инофрмация по таблице orders:')
orders.info()
print('------------------------------')
print('\n')
print('Инофрмация по таблице costs:')
costs.info()
# Out:
# Инофрмация по таблице visits:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# ------------------------------
#
#
# Инофрмация по таблице orders:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# ...

# %% [markdown]
# Согласно полученной информации по отчетам visits, orders и costs - необходимо поправить типы данных в столбцах:
# - Session Start (visits) привести к формату datetime
# - Session End (visits) привести к формату datetime
# - Event Dt (orders) привести к формату datetime
# - dt (costs) привести к формату datetime
#
# А также произвести правку названия заголовков столбцов в соответствие с хорошим стилем.

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns.values]
costs.columns = [x.lower().replace(' ', '_') for x in costs.columns.values]

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Супер, отлично преобразованы названия колонок в [snake_case](https://techrocks.ru/2018/08/09/most-common-programming-case-types/) красивым методом👍
#
# </div>

# %%
display(visits.columns, orders.columns, costs.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# В результате преобразований наименования столбцов приведены к оптимальному стилю для дальнейшего анализа данных.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
visits.info()
print('-----------------')
orders.info()
print('-----------------')
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# -----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что преобразования типов все в одном месте.
#
# </div>

# %% [markdown]
# В результате выполнены преобразования и оптимизация типов данных.

# %% [markdown]
# <b> Поиск явных дубликатов:

# %%
display(visits.duplicated().sum())
# Out:
# 0

# %%
display(orders.duplicated().sum())
# Out:
# 0

# %%
display(costs.duplicated().sum())
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, проверено наличие дубликатов.
#
# </div>

# %%
display(sorted(costs['channel'].unique()))
# Out:
# ['AdNonSense',
#  'FaceBoom',
#  'LeapBob',
#  'MediaTornado',
#  'OppleCreativeMedia',
#  'RocketSuperAds',
#  'TipTop',
#  'WahooNetBanner',
#  'YRabbit',
#  'lambdaMediaAds']

# %%
display(sorted(visits['region'].unique()))
# Out:
# ['France', 'Germany', 'UK', 'United States']

# %%
display(sorted(visits['device'].unique()))
# Out:
# ['Android', 'Mac', 'PC', 'iPhone']

# %% [markdown]
# Поиск явных и неявных дубликтов не выдал результатов. Дубликаты отсутствуют.

# %% [markdown]
# ## Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):
    profiles = (sessions.sort_values(by = ['user_id', 'session_start'])           
                        .groupby('user_id').agg({'session_start' : 'first',       
                                                 'channel': 'first',
                                                 'device': 'first',
                                                 'region': 'first'})                                 
                        .rename(columns = {'session_start' : 'first_ts'})  
                        .reset_index()                                           
               )
    profiles['dt'] = profiles['first_ts'].dt.date                                 
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')     
    
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())   
            
    new_users = profiles.groupby(['dt', 'channel']).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'unique_users'}).reset_index()
    ad_costs = ad_costs.merge(new_users, on = ['dt', 'channel'], how = 'left')
    
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    profiles = profiles.merge(ad_costs[['dt', 'channel', 'acquisition_cost']], on = ['dt', 'channel'], how = 'left')
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles

# %%
# функция для расчёта удержания

def get_retention(profiles, sessions, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
    dimensions = ['payer'] + dimensions
    
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    def group_by_dimensions(df, dims, horizon_days):     
        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')      
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) 
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)                                   
        result = result.div(result['cohort_size'], axis = 0)                                                     
        result = result[['cohort_size'] + list(range(horizon_days))]                                             
        result['cohort_size'] = cohort_sizes
        return result
    
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(profiles, purchases, observation_date, horizon_days, dimensions = [], ignore_horizon = False):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    first_purchases = purchases.sort_values(by = ['user_id', 'event_dt']).groupby('user_id').agg({'event_dt': 'first'}).reset_index()

    result_raw = result_raw.merge(first_purchases[['user_id', 'event_dt']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['event_dt'] - result_raw['first_ts']).dt.days
    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']  
    
    def group_by_dimensions(df, dims, horizon_days):  

        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')
        
        result = result.fillna(0).cumsum(axis = 1)
        
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) 
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)                                   
        
        result = result.div(result['cohort_size'], axis = 0) 
        result = result[['cohort_size'] + list(range(horizon_days))]                                             
        result['cohort_size'] = cohort_sizes
        return result
    
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    if 'cohort' in dimensions: dimensions = []
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(profiles, purchases, observation_date, horizon_days, dimensions = [], ignore_horizon = False):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    result_raw = result_raw.merge(purchases[['user_id', 'event_dt', 'revenue']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['event_dt'] - result_raw['first_ts']).dt.days
    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']  
    
    def group_by_dimensions(df, dims, horizon_days):  

        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'revenue', aggfunc = 'sum')
        
        result = result.fillna(0).cumsum(axis = 1)
        
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) 
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)
        
        result = result.div(result['cohort_size'], axis = 0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        cac = cac.groupby(dims).agg({'acquisition_cost': 'mean'}).rename(columns = {'acquisition_cost': 'cac'})
        
        roi = result.div(cac['cac'], axis = 0)

        roi = roi[~roi['cohort_size'].isin([np.inf])]
        
        roi['cohort_size'] = cohort_sizes
        roi['cac'] = cac['cac']
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]
        
        return result, roi

    result_grouped, roi_groupped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    if 'cohort' in dimensions: dimensions = []
    result_in_time, roi_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    return result_raw, result_grouped, result_in_time, roi_groupped, roi_in_time

# %%
def filter_data(df, window):

    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window = 7):
    
    plt.subplots(figsize = (15, 10))
    
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users' 
        retention = retention.reset_index().set_index(['cohort', 'payer']) 
    
    retention = retention.drop(columns = ['cohort_size', 0]) 
    retention_history = retention_history.drop(columns = ['cohort_size'])[[horizon - 1]]
    
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(grid = True, ax = ax1)
    plt.legend()
    plt.xlabel('Lifetime')
    plt.title('Удержание платящих пользователей')  
    
    ax2 = plt.subplot(2, 2, 2, sharey = ax1)
    retention.query('payer == False').droplevel('payer').T.plot(grid = True, ax = ax2)
    plt.legend()
    plt.xlabel('Lifetime')
    plt.title('Удержание неплатящих пользователей')
    
    ax3 = plt.subplot(2, 2, 3)
    columns = [name for name in retention_history.index.names if name not in ['dt', 'payer']] 
    filtered_data = retention_history.query('payer == True').pivot_table(index = 'dt', columns = columns, values = horizon - 1, aggfunc = 'mean')
    filter_data(filtered_data, window).plot(grid = True, ax = ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания платящих пользователей на {}-й день'.format(horizon))  
    
    ax4 = plt.subplot(2, 2, 4, sharey = ax3)
    filtered_data = retention_history.query('payer == False').pivot_table(index = 'dt', columns = columns, values = horizon - 1, aggfunc = 'mean')
    filter_data(filtered_data, window).plot(grid = True, ax = ax4)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания неплатящих пользователей на {}-й день'.format(horizon))   
    
    plt.tight_layout() 
    
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window = 7):
    
    plt.subplots(figsize = (15, 10))
    
    conversion = conversion.drop(columns = ['cohort_size']) 
    conversion_history = conversion_history.drop(columns = ['cohort_size'])[[horizon - 1]]
    
    ax1 = plt.subplot(2, 2, 1)
    conversion.T.plot(grid = True, ax = ax1)
    plt.legend()
    plt.xlabel('Lifetime')
    plt.title('Конверсия пользователей')  
    
    ax2 = plt.subplot(2, 2, 2, sharey = ax1)
    
    columns = [name for name in conversion_history.index.names if name not in ['dt']] 
    filtered_data = conversion_history.pivot_table(index = 'dt', columns = columns, values = horizon - 1, aggfunc = 'mean')
    filter_data(filtered_data, window).plot(grid = True, ax = ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))  
    
    plt.tight_layout() 
    
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window = 7):
    
    plt.subplots(figsize = (20, 10))
    
    ltv = ltv.drop(columns = ['cohort_size']) 
    ltv_history = ltv_history.drop(columns = ['cohort_size'])[[horizon - 1]]
    
    cac_history = roi_history[['cac']]
    
    roi = roi.drop(columns = ['cohort_size', 'cac']) 
    roi_history = roi_history.drop(columns = ['cohort_size', 'cac'])[[horizon - 1]]
    
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid = True, ax = ax1)
    plt.legend()
    plt.xlabel('Lifetime')
    plt.title('LTV')  
    
    ax2 = plt.subplot(2, 3, 2, sharey = ax1)

    columns = [name for name in ltv_history.index.names if name not in ['dt']] 
    filtered_data = ltv_history.pivot_table(index = 'dt', columns = columns, values = horizon - 1, aggfunc = 'mean')
    filter_data(filtered_data, window).plot(grid = True, ax = ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))  
    
    ax3 = plt.subplot(2, 3, 3, sharey = ax1)

    columns = [name for name in cac_history.index.names if name not in ['dt']] 
    filtered_data = cac_history.pivot_table(index = 'dt', columns = columns, values = 'cac', aggfunc = 'mean')
    filter_data(filtered_data, window).plot(grid = True, ax = ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')  
    
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid = True, ax = ax4)
    plt.axhline(y = 1, color = 'red', linestyle = '--', label = 'Уровень окупаемости')
    plt.legend()
    plt.xlabel('Lifetime')
    plt.title('ROI')  
    
    ax5 = plt.subplot(2, 3, 5, sharey = ax4)

    columns = [name for name in roi_history.index.names if name not in ['dt']] 
    filtered_data = roi_history.pivot_table(index = 'dt', columns = columns, values = horizon - 1, aggfunc = 'mean')
    filter_data(filtered_data, window).plot(grid = True, ax = ax5)
    plt.axhline(y = 1, color = 'red', linestyle = '--', label = 'Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))  

    plt.tight_layout()
    
    plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Супер, созданы все необходимые функции для дальнейшего исследования👍
#
# </div>

# %% [markdown]
# ## Проведите исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ### Создание пользовательских профилей. Определение минимальной и максимальной даты привлечения пользователей.

# %%
# доступный интервал привлечения пользователей
min_analysis_date = visits['session_start'].min()
observation_date = datetime(2019, 11, 1).date()
display(min_analysis_date, observation_date)
# Out:
# Timestamp('2019-05-01 00:00:41')
# datetime.date(2019, 11, 1)

# %%
# расчет максимальной даты привлечения
analysis_horizon = 14
max_analysis_date = observation_date - timedelta(days=analysis_horizon - 1)
display(max_analysis_date)
# Out:
# datetime.date(2019, 10, 19)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Отлично, корректно определены минимальная и максимальная дата привлечения пользователей.
#
# </div>

# %%
profiles =  get_profiles(visits, orders, costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# Результат — 150008 пользовательских профилей, в каждом из которых есть данные о дате первого посещения и рекламном источнике, который мотивировал пользователя посетить интернет-магазин. Такие данные значительно упрощают дальнейший анализ.

# %% [markdown]
# ### Определение, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построение таблицы, отражающую количество пользователей и долю платящих из каждой страны.

# %%
display(
    profiles
    .groupby('region')
    .agg({'user_id': 'nunique', 'payer': 'mean'})
    .sort_values(by=['payer'], ascending=False)
)
# Out:
#                user_id     payer
# region
# United States   100002  0.069019
# Germany          14981  0.041119
# UK               17575  0.039829
# France           17450  0.037994

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, корректно построена сводная таблица по странам!
#
# </div>

# %% [markdown]
# В анализе представлены пользователи из 4 стран: США, Германия, Франция и Великобритания. Согласно полученной таблице на США приходится больше всего платящих пользователей с долей 6,9% и больше всего пользователей из США с количеством 100002, у прочих представленных стран доля на уровне 3-4%.

# %% [markdown]
# ### Определение, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построение таблицы, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
display(
    profiles
    .groupby('device')
    .agg({'user_id': 'nunique', 'payer': 'mean'})
    .sort_values(by=['payer'], ascending=False)
)
# Out:
#          user_id     payer
# device
# Mac        30042  0.063644
# iPhone     54479  0.062079
# Android    35032  0.058518
# PC         30455  0.050468

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# У тебя три блока с похожим кодом, было здорово обернуть построение сводной и вывод ее в функцию для удобства.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Спасибо за комментарий, в будущих проектах сделаю таким образом
#
# </div>

# %% [markdown]
# В анализе представлены пользователи 4 устройств: Mac, iPhone, Android, PC. Согласно полученной таблице на пользователей MAC приходится больше всего платящих пользователей с долей 6,4%, в тоже время количество пользователей MAC меньше всего 30042, доля платящих пользователей iPhone составляет 6,2% с самым большим количеством пользователей, доля пользователей Android 5,8%, наименьшая доля приходится на пользователей PC с долей 5%.

# %% [markdown]
# ### Изучение рекламных источников привлечения и определение каналов, из которых пришло больше всего платящих пользователей. Построение таблицы, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
display(
    profiles
    .groupby('channel')
    .agg({'user_id': 'nunique', 'payer': 'mean'})
    .sort_values(by=['payer'], ascending=False)
)
# Out:
#                     user_id     payer
# channel
# FaceBoom              29144  0.122049
# AdNonSense             3880  0.113402
# lambdaMediaAds         2149  0.104700
# TipTop                19561  0.096007
# RocketSuperAds         4448  0.079137
# WahooNetBanner         8553  0.052964
# YRabbit                4312  0.038265
# MediaTornado           4364  0.035747
# LeapBob                8553  0.030633
# OppleCreativeMedia     8605  0.027077
# organic               56439  0.020553

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, df отсортирован 👍
#
# </div>

# %% [markdown]
# Всего представлено 11 рекламных источников привлечения. Наиболее успешный канал с долей платящих пользователей в 12,2% является FaceBoom, и самым большим количеством пользователей 29144, привлеченных по неорганическим рекламным каналам, также в топ-3 с долей 11,3% и 10,4% входят каналы: AdNonSense и lambdaMediaAds, но количество привлеченных пользователей по данным каналам наименьшее.
# Наименьшую долю платящих пользователей 2% показал канал привлечения: organic, но количество пользователей привлеченных по данному каналу 56439 самое высокое.

# %% [markdown]
# <b> Промежуточный вывод:</b>
# - В анализе представлены пользователи из 4 стран: США, Германия, Франция и Великобритания. Больше всего пользователей из США с количсетвом 100002, с долей платящих пользователей 6,9%. На втором месте Германия 14981 с долей платящих пользователей 4,1%.
# - В анализе представлены пользователи 4 устройств: Mac, iPhone, Android, PC. Согласно полученной таблице на пользователей MAC приходится больше всего платящих пользователей с долей 6,4%, в тоже время количество пользователей MAC меньше всего 30042, доля платящих пользователей iPhone составляет 6,2% с самым большим количеством пользователей, доля пользователей Android 5,8%, наименьшая доля приходится на пользователей PC с долей 5%.
# - Всего представлено 11 рекламных источников привлечения. Наиболее успешный канал с долей платящих пользователей в 12,2% является FaceBoom, и самым большим количеством пользователей 29144, привлеченных по неорганическим рекламным каналам, также в топ-3 с долей 11,3% и 10,4% входят каналы: AdNonSense и lambdaMediaAds, но количество привлеченных пользователей по данным каналам наименьшее. Наименьшую долю платящих пользователей 2% показал канал привлечения: organic, но количество пользователей привлеченных по данному каналу 56439 самое высокое.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Напиши, пожалуйста, промежуточные выводы по «Шаг 3. Проведите исследовательский анализ данных»
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Промежуточный вывод добавлен
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# ## Маркетинг
#
# Выясните:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %%
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# ### Расчет затрат на маркетинг:

# %%
total_costs = profiles['acquisition_cost'].sum()
print('Всего денег потратили:', total_costs)
# Out:
# Всего денег потратили: 105497.29999999999

# %% [markdown]
# ### Затраты на каждый источник:

# %%
display(
    profiles
    .groupby('channel')
    .agg({'acquisition_cost': 'sum'})
    .sort_values(by=['acquisition_cost'], ascending=False)
)
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Тут можно подсчитать доли затрат по каждому источнику, чтобы определить какая доля рекламного бюджета была выделена на два источника.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# а как лучше добавить долю? сгрупировать по каналу и добавить функцию 'acquisition_cost': 'mean'?
#
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">v2 Комментарий ревьюера (желтый)</font></h5>
#
# Можно посчитать сумму и поделить все значения на сумму.
#
# </div>

# %% [markdown]
# Согласно полученной таблице, видим, что наибольшие затраты на рекламу по источникам наблюдаются по каналу TipTop, вместе с тем, доля платящих пользователей составляет 9,6%, и не входит в топ-3 по доле платящих пользователей.
#
# lambdaMediaAds - является одним из самых дешевых источников привлечения пользователей, но в то же время каналом с самой высокой долей привлечения платящих пользователей (топ-3).
#
# Наблюдается отсутствие затрат на канал organic - это привлеченные пользователи через поисковые системы.

# %% [markdown]
# ### Затраты по времени:

# %%
display(
    profiles
    .groupby('month')
    .agg({'acquisition_cost': 'sum'})
    .sort_values(by=['acquisition_cost'], ascending=False)
)
# Out:
#             acquisition_cost
# month
# 2019-09-01         22441.340
# 2019-10-01         20882.415
# 2019-08-01         20657.870
# 2019-07-01         16447.060
# 2019-06-01         15090.045
# 2019-05-01          9978.570

# %%
display(
    profiles
    .groupby('month')
    .agg({'acquisition_cost': 'median'})
    .sort_values(by=['acquisition_cost'], ascending=False)
)
# Out:
#             acquisition_cost
# month
# 2019-06-01          0.255319
# 2019-10-01          0.254630
# 2019-09-01          0.254386
# 2019-07-01          0.253968
# 2019-08-01          0.253521
# 2019-05-01          0.000000

# %% [markdown]
# Наблюдается равномерный рост затрат за каждый месяц, в сентябре было увеличение затрат в суммарном отношении, в сравнении с октябрем, но это была единовременная акция в данным месяц, так как медианное значение демонстрирует самый высокий показатель в июне, октябре и сентябре.

# %%
profiles.pivot_table(
    index='month', columns='channel', values='acquisition_cost', aggfunc='sum'
).plot.area(stacked=False, grid=True, figsize=(25, 10))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Спасибо, красиво визуализированы данные затрат по каналам.
#
# Но на данном графике не отображается общая сумма расходов. Визуализируй, пожалуйста, траты на маркетинг по каналам с помощью [.plot.area](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.area.html)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# добавлено
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# ### Расчет, сколько в среднем стоило привлечение одного пользователя из каждого источника. Расчет среднего CAC на одного пользователя для всего проекта и для каждого источника трафика.

# %%
profiles_nonorganic = profiles.query('channel != "organic"')
cohort_sizes_CAC = (
            profiles_nonorganic.groupby('user_id')
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
)
cohort_sizes_CAC_count = cohort_sizes_CAC.count()
cohort_sizes_CAC_count
# Out:
# cohort_size    93569
# dtype: int64

# %%
CAC = total_costs/cohort_sizes_CAC_count
CAC
# Out:
# cohort_size    1.127481
# dtype: float64

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Тут следует также привести расчет САС для посетителей, привлеченных только по рекламным каналам, т.е. исключив органических пользователей.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# поправлено
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# CAC на одного пользователя для всего проекта составляет 1.127481

# %% [markdown]
# Расчет среднего CAC на одного пользователя для каждого источника трафика:

# %%
def CAC_channel (channel):

    costs_for_users = profiles_nonorganic[profiles_nonorganic['channel'] == channel]
    costs_for_users_calc = costs_for_users['acquisition_cost'].sum()/costs_for_users['user_id'].count()
    return costs_for_users_calc

# %%
print(
    ' TipTop:', CAC_channel('TipTop'), '\n',
    'FaceBoom:', CAC_channel('FaceBoom'), '\n',
    'WahooNetBanner:', CAC_channel('WahooNetBanner'), '\n',
    'AdNonSense:', CAC_channel('AdNonSense'), '\n',
    'OppleCreativeMedia:', CAC_channel('OppleCreativeMedia'), '\n',
    'RocketSuperAds:', CAC_channel('RocketSuperAds'), '\n',
    'LeapBob:', CAC_channel('LeapBob'), '\n',
    'lambdaMediaAds:', CAC_channel('lambdaMediaAds'), '\n',
    'MediaTornado:', CAC_channel('MediaTornado'), '\n', 
    'YRabbit:', CAC_channel('YRabbit'), '\n',
)
# Out:
#  TipTop: 2.799003118449977
#  FaceBoom: 1.1132857534998628
#  WahooNetBanner: 0.60224482637671
#  AdNonSense: 1.0080541237113403
#  OppleCreativeMedia: 0.25
#  RocketSuperAds: 0.4120953237410072
#  LeapBob: 0.21017186951946684
#  lambdaMediaAds: 0.7248022335970218
#  MediaTornado: 0.21871677360219982
#  YRabbit: 0.21897495361781077

# %% [markdown]
# Согласно полученной информации видим, что затраты на одного пользователя по источникам трафика TipTop превышают затраты на одного пользователя по всему проекту. По остальным источникам затраты на одного пользователя не превышают данный показатель. Наименьшии затраты по следующим каналам: MediaTornado, YRabbit, LeapBob и OppleCreativeMedia.

# %%
profiles_nonorganic.pivot_table(
    index='month', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot.area(stacked=False, grid=True, figsize=(25, 10))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# <b> Промежуточные выводы: </b>
# - CAC на одного пользователя для всего проекта составляет 1.127481
# - Согласно полученной информации видим, что затраты на одного пользователя по источникам трафика TipTop превышают затраты на одного пользователя по всему проекту. По остальным источникам затраты на одного пользователя не превышают данный показатель. Наименьшии затраты по следующим каналам: MediaTornado, YRabbit, LeapBob и OppleCreativeMedia.
#
# Рекомендуется искать способы оптимизации затрат на рекламный канал TipTop, так как данный канал по количеству привлеченных платящих пользователей не является самым высоким, следует работать над увеличением доли платящих уже существующих пользователей.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Напиши, пожалуйста, промежуточные выводы по «Шаг 4. Маркетинг»
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# добавлено
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# ## Оцените окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Проанализируйте общую окупаемость рекламы

# %%
profiles = get_profiles(visits, orders, costs)
profiles_nonorganic_analise = profiles.query('channel != "organic"')
profiles_nonorganic_analise
# Out:
#              user_id            first_ts       channel   device  \
# 0             599326 2019-05-07 20:58:57      FaceBoom      Mac
# 1            4919697 2019-07-09 12:46:07      FaceBoom   iPhone
# 3           22593348 2019-08-22 21:35:48    AdNonSense       PC
# 4           31989216 2019-10-02 00:07:44       YRabbit   iPhone
# 7           46006712 2019-06-30 03:46:29    AdNonSense  Android
# ...              ...                 ...           ...      ...
# 149999  999942424543 2019-05-24 21:03:26        TipTop   iPhone
# 150001  999949280903 2019-08-12 06:47:27      FaceBoom      Mac
# 150003  999956196527 2019-09-28 08:33:02        TipTop   iPhone
# 150005  999976332130 2019-07-23 02:57:06        TipTop   iPhone
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado       PC
#
#                region          dt      month  payer  acquisition_cost
# 0       United States  2019-05-07 2019-05-01   True          1.088172
# ...

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Исключи, пожалуйста, органиков из анализа - мы же за них ничего не платим.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# поправлено
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_nonorganic_analise, orders, observation_date, horizon_days
)

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что замечен тот факт, что реклама не окупается, молодец 😃
#
# </div>

# %% [markdown]
# По графикам можно сделать такие выводы:
# - Реклама ц целом по проекту не окупается. ROI к концу второй недели не приближается к границе окупаемости.
# - Видим, что в динамике проект окупалься в мае и июне, и частично в июле, далее наблюдается спад.
# - CAC не стабилен. Налюдается рост затрат на рекламу.
# - На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
#
# Видим, что затраты на рекламу в рассматриваемый период не достигают уровня окупаемости, далее рассмотрим причины отсутствия окупаемости.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по устройствам

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_nonorganic_analise, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Да, хорошая визуализация, выводы верные!
#
# </div>

# %% [markdown]
# Согласно полученному результату LTV по пользователям PC ниже чем по прочим устройствам, но как видно из графиков, у пользователей PC выше окупаемость, к концу недели превышает окупаемость, в тоже время и наименьший показатель CAC. Также наблюдается снижение окупаемости в динамике к концу наблюдаемого периода. Ниже всех окупаемость по устройствам iPhone и Mac. Высокие затраты на привлечение пользователей iPhone и MAC приводят к снижению общей окупаемости по проекту.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_nonorganic_analise, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Полный вывод, который соответствует построенным выше графикам, спасибо!
#
# </div>

# %% [markdown]
# Для пользователей из США наблюдается спад в окупаемости. Независимо от того, что прибыльность по пользователям из США превышает другие регионы, CAC намного больше превышает прочие регионы, в связи с чем окупаемость ниже чем в других регионах.
# Наблюдается, что окупаемость по пользователям из Франции, Германии и Великобритании показывают положительную динамику. Можно сделать вывод, что на снижение окупаемости по проекту в целом, влияют высокие затраты на привлечение пользователей из США.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_nonorganic_analise, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Согласно полученным графикам, видим, что прибыльность по каналу LambdaMediaAds выше чем по прочим каналам привлечения. По каналу TipTop также наблюдается высокая прибыльность, но затраты на привлечение по каналу TipTop намного превышает прочие каналы.
# Видим, что отсутствует окупаемость по каналу TipTop, также отсутствует окупаемость по каналам: FaceBoom и AdNoneSense.
# В динамике наблюдается стабильная окупаемость по всем каналам, кроме FaceBoom и TipTop - можно сделать вывод, что данные два канала привлечения приводят к снижению общей окупаемости по проекту, в связи с высокими затратами на привлечение по данным каналам и невысокой прибыльности по данным каналам.

# %% [markdown]
# ### Построим и изучим графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.

# %% [markdown]
# #### конверсия и удержания в разбивке по устройствам

# %%
# конверсия с разбивкой по устройствам
dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_nonorganic_analise, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия по устройствам, показывает, что пользователи MAC конвертируются выше чем пользователи прочих устройств, конверсия пользователей PC ниже чем по пользователям прочих устройств.
# Конверсия 14-го дня показывает, что в некоторые дни конверсия по пользователям PC была выше конверсии пользователей MAC, например в середине июня и начале августа, но конверсия по устройству PC демонстрирует высокую валатильность. В целом пользователи устроств MAC, iPhone и Android демонстрируют более высокую конверсию.

# %%
# удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_nonorganic_analise, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Видим, что платящие пользователи PC и MAC демонстрируют более высокий показатель, у пользователей PC и MAC наблюдаются спады в динамике удержания платящих пользователей 14-го дня. В общем показатели показывают примерно похожие результаты, отсутствуют выделяющиеся устройства.
#
# Не смотря на более низкую конверсию, видим, что уровень удержания для пользователей устройств PC и MAC более высокий, для маркетологов видится более перспективным и дешевым вложением в рекламу будет для пользователей PC и MAC.

# %% [markdown]
# #### конверсия и удержания в разбивке по странам

# %%
# конверсия с разбивкой по странам
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_nonorganic_analise, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Видим, что конверсия по США выделяется от остальных регионов, конверсия по США выше чем по остальным регионам.

# %%
# удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_nonorganic_analise, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Независимо от высокой конверсии, наблюдается самое низкое удержание платящих пользователей в регионе США. Удержание ниже на 10% чем в остальных регионах. В связи с этим затраты на привлечение новых пользователей в США выше, чем в остальных регионах. Для маркетологов важно было бы работать с платящими пользователями, чтобы увеличить уровень удержания, и тем самым вложения в рекламные акции для платящих пользователей будут более дешевые, чем привлечение новых пользователей.

# %% [markdown]
# #### конверсия и удержания в разбивке по рекламным каналам

# %%
# конверсия с разбивкой по рекламным каналам
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_nonorganic_analise, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самая высокая конверсия наблюдается по каналу FaceBoom. В Динамике конверсии пользователей на 14-й день канал привлечения LambdaMediaAds в июне продемонстрировал скачок конверсии, по остальным каналам конверсия показывает более стабильный показатель в динамике.

# %%
# удержание с разбивкой по рекламным каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles_nonorganic_analise, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Красивое и понятное сравнение, спасибо!
#
# </div>

# %% [markdown]
# Удержания по каналу FaceBoom демонстрирует наименьший показатель, что говорит о плохом удержании платящих пользователей. Канал AdNonSense также демонстрирует наименьший показатель удержания. Показатели удержания по данным каналам меньше примерно на 20%, что увеличивает расходы на привлечение новых пользователей по данным каналам.

# %% [markdown]
# ## Напишите выводы
# - Выделите причины неэффективности привлечения пользователей;
# - Сформируйте рекомендации для отдела маркетинга для повышения эффективности.

# %% [markdown]
# 1. <b> Первичная обработка данных. </b>
#
# Были загружены данные о визитах, заказах и расходах в переменные.
#
# В результате оптимизации данных для анализа были адаптированы типы данных и наименования колонок.
#
# По результатам проверки дубликатов в данных обнаружено не было.
#
#
# 2. <b> Исследовательский анализ данных. </b>
#
# В доступе 150008 пользовательских профилей, в каждом из которых есть данные о дате первого посещения и рекламном источнике, который мотивировал пользователя посетить интернет-магазин.
#
# <b> Профили по странам </b>
#
# |region	      | user_id	 |  payer  |
# |-------------|----------|---------|
# |United States|	100002	 | 0.069019|
# |Germany	  | 14981	 | 0.041119|
# |UK	          | 17575	 | 0.039829|
# |France       |	17450	 | 0.037994|
#
#
# В анализе представлены пользователи из 4 стран: США, Германия, Франция и Великобритания. Согласно полученной таблице на США приходится больше всего платящих пользователей с долей 6,9% и больше всего пользователей из США с количеством 100002, у прочих представленных стран доля на уровне 3-4%.
#
# <b> Профили по устройствам </b>
#
# |device	|user_id|	payer|
# |-------|-------|--------|
# |Mac	|30042	|0.063644|
# |iPhone	|54479	|0.062079|
# |Android|35032	|0.058518|
# |PC	    |30455	|0.050468|
#
# В анализе представлены пользователи 4 устройств: Mac, iPhone, Android, PC. Согласно полученной таблице на пользователей MAC приходится больше всего платящих пользователей с долей 6,4%, в тоже время количество пользователей MAC меньше всего 30042, доля платящих пользователей iPhone составляет 6,2% с самым большим количеством пользователей, доля пользователей Android 5,8%, наименьшая доля приходится на пользователей PC с долей 5%.
#
# <b> Профили по рекламным каналам </b>
#
# |channel           |user_id| payer	|
# |------------------|-------|--------|
# |FaceBoom	       |29144  |0.122049|
# |AdNonSense	       |3880   |0.113402|
# |lambdaMediaAds	   |2149   |0.104700|
# |TipTop	           |19561  |0.096007|
# |RocketSuperAds	   |4448   |0.079137|
# |WahooNetBanner	   |8553   |0.052964|
# |YRabbit	       |4312   |0.038265|
# |MediaTornado	   |4364   |0.035747|
# |LeapBob	       |8553   |0.030633|
# |OppleCreativeMedia|8605   |0.027077|
# |organic	       |56439  |0.020553|
#
# Всего представлено 11 рекламных источников привлечения. Наиболее успешный канал с долей платящих пользователей в 12,2% является FaceBoom, и самым большим количеством пользователей 29144, привлеченных по неорганическим рекламным каналам, также в топ-3 с долей 11,3% и 10,4% входят каналы: AdNonSense и lambdaMediaAds, но количество привлеченных пользователей по данным каналам наименьшее. Наименьшую долю платящих пользователей 2% показал канал привлечения: organic, но количество пользователей привлеченных по данному каналу 56439 - самое высокое.
#
#
# 3. <b> Маркетинг. </b>
#
# Всего было потрачено на рекламные акции в рассматриваемый период: 105497.3
#
# <b>Затраты на каждый источник </b>
#
# | channel          |	acquisition_cost |
# |------------------|---------------------|
# |TipTop            |	54751.30         |
# |FaceBoom          |	32445.60         |
# |WahooNetBanner    |	5151.00          |
# |AdNonSense        |	3911.25          |
# |OppleCreativeMedia|	2151.25          |
# |RocketSuperAds	   |    1833.00          |
# |LeapBob	       |    1797.60          |
# |lambdaMediaAds	   |    1557.60          |
# |MediaTornado	   |     954.48          |
# |YRabbit	       |     944.22          |
# |organic	       |     0.00            |
#
# Согласно полученной таблице, видим, что наибольшие затраты на рекламу по источникам наблюдаются по каналу TipTop, вместе с тем, доля платящих пользователей составляет 9,6%, и не входит в топ-3 по доле платящих пользователей.
#
# lambdaMediaAds - является одним из самых дешевых источников привлечения пользователей, но в то же время каналом с самой высокой долей привлечения платящих пользователей (топ-3).
#
# Наблюдается отсутствие затрат на канал organic - это привлеченные пользователи через поисковые системы.
#
# В целях рекомендации маркетологам можно сделать вывод на данном этапе, что затраты на рекламу по каналу TipTop не оправдывают себя, а также стоит обратить внимание на канал привлечения lambdaMediaAds - так как наблюдаются небольшие затраты на рекламу, но высокая доля платящих пользователей.
#
# А также более активно работать с пользователями, которые привлекаются по органическим каналам.
#
# <b> Затраты по времени </b>
#
#
# |month	   |acquisition_cost_sum|median  |
# |----------|--------------------|--------|
# |2019-09-01|	22441.340       |0.254386|
# |2019-10-01|	20882.415       |0.254630|
# |2019-08-01|	20657.870       |0.253521|
# |2019-07-01|	16447.060       |0.253968|
# |2019-06-01|	15090.045       |0.255319|
# |2019-05-01|	9978.570        |0.000000|
#
# Наблюдается равномерный рост затрат за каждый месяц, в сентябре было увеличение затрат в суммарном отношении, в сравнении с октябрем, но это была единовременная акция в данным месяц, так как медианное значение демонстрирует самый высокий показатель в июне, октябре и сентябре.
#
# <b> Расчет, сколько в среднем стоило привлечение одного пользователя из каждого источника. Расчет среднего CAC на одного пользователя для всего проекта и для каждого источника трафика. </b>
#
# CAC на одного пользователя для всего проекта составляет 1.127481
#
# <b> Расчет среднего CAC на одного пользователя для каждого источника трафика </b>
#
# |channel           | CAC               |
# |------------------|-------------------|
# |TipTop            |2.799003118449977  |
# |FaceBoom          |1.1132857534998628 |
# |WahooNetBanner    |0.60224482637671   |
# |AdNonSense        |1.0080541237113403 |
# |OppleCreativeMedia|0.25               |
# |RocketSuperAds    |0.4120953237410072 |
# |LeapBob           |0.21017186951946684|
# |lambdaMediaAds    |0.7248022335970218 |
# |MediaTornado      |0.21871677360219982|
# |YRabbit           |0.21897495361781077|
# |organic           |0.0                |
#
# Согласно полученной информации видим, что затраты на одного пользователя по источникам трафика TipTop превышают затраты на одного пользователя по всему проекту. По остальным источникам затраты на одного пользователя не превышают данный показатель. Наименьшии затраты по следующим каналам: MediaTornado, YRabbit, LeapBob и OppleCreativeMedia.
#
# 4. <b> Оценика окупаемости рекламы для привлечения пользователей </b>
#
# <b> анализ общей окупаемости рекламы </b>
#
# По графикам можно сделать такие выводы:
#
# - Реклама в целом по проекту не окупается. ROI к концу второй недели приближается к границе окупаемости.
# - Видим, что в динамике проект окупалься в мае и июне, и частично в июле, далее наблюдается спад.
# - CAC не стабилен. Налюдается рост затрат на рекламу.
# - На LTV влияет сезонный фактор, но и этот показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
#
# Видим, что затраты на рекламу в рассматриваемый период не достигают уровня окупаемости, далее рассмотрим причины отсутствия окупаемости.
#
# <b> окупаемость рекламы с разбивкой по устройствам </b>
#
# Согласно полученному результату LTV по пользователям PC ниже чем по прочим устройствам, но как видно из графиков, у пользователей PC выше окупаемость, к концу недели превышает окупаемость, в тоже время и наименьший показатель CAC. Также наблюдается снижение окупаемости в динамике к концу наблюдаемого периода. Ниже всех окупаемость по устройствам iPhone и Mac. Высокие затраты на привлечение пользователей iPhone и MAC приводят к снижению общей окупаемости по проекту.
#
# <b> окупаемость рекламы с разбивкой по странам </b>
#
# Для пользователей из США наблюдается спад в окупаемости. Независимо от того, что прибыльность по пользователям из США превышает другие регионы, CAC намного больше превышает прочие регионы, в связи с чем окупаемость ниже чем в других регионах. Наблюдается, что окупаемость по пользователям из Франции, Германии и Великобритании показывают положительную динамику. Можно сделать вывод, что на снижение окупаемости по проекту в целом, влияют высокие затраты на привлечение пользователей из США.
#
# <b> окупаемость рекламы с разбивкой по рекламным каналам </b>
#
# Согласно полученным графикам, видим, что прибыльность по каналу LambdaMediaAds выше чем по прочим каналам привлечения. По каналу TipTop также наблюдается высокая прибыльность, но затраты на привлечение по каналу TipTop намного превышает прочие каналы. Видим, что отсутствует окупаемость по каналу TipTop, также отсутствует окупаемость по каналам: FaceBoom и AdNoneSense. В динамике наблюдается стабильная окупаемость по всем каналам, кроме FaceBoom и TipTop - можно сделать вывод, что данные два канала привлечения приводят к снижению общей окупаемости по проекту, в связи с высокими затратами на привлечение по данным каналам и невысокой прибыльности по данным каналам.
#
# <b> анализ конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам. </b>
#
# <b> конверсия и удержания в разбивке по устройствам </b>
#
# Конверсия по устройствам, показывает, что пользователи MAC конвертируются выше чем пользователи прочих устройств, конверсия пользователей PC ниже чем по пользователям прочих устройств. Конверсия 14-го дня показывает, что в некоторые дни конверсия по пользователям PC была выше конверсии пользователей MAC, например в середине июня и начале августа, но конверсия по устройству PC демонстрирует высокую валатильность. В целом пользователи устроств MAC, iPhone и Android демонстрируют более высокую конверсию.
#
# Видим, что платящие пользователи PC и MAC демонстрируют более высокий показатель, у пользователей PC и MAC наблюдаются спады в динамике удержания платящих пользователей 14-го дня. В общем показатели показывают примерно похожие результаты, отсутствуют выделяющиеся устройства.
#
# Не смотря на более низкую конверсию, видим, что уровень удержания для пользователей устройств PC и MAC более высокий, для маркетологов видится более перспективным и дешевым вложением в рекламу будет для пользователей PC и MAC.
#
# <b> конверсия и удержания в разбивке по странам </b>
#
# Конверсия по США выше чем по остальным регионам.
#
# Независимо от высокой конверсии, наблюдается самое низкое удержание платящих пользователей в регионе США. Удержание ниже на 10% чем в остальных регионах. В связи с этим затраты на привлечение новых пользователей в США выше, чем в остальных регионах. Для маркетологов важно было бы работать с платящими пользователями, чтобы увеличить уровень удержания, и тем самым вложения в рекламные акции для платящих пользователей будут более дешевые, чем привлечение новых пользователей.
#
# <b> конверсия и удержания в разбивке по рекламным каналам </b>
#
# Самая высокая конверсия наблюдается по каналу FaceBoom. В Динамике конверсии пользователей на 14-й день канал привлечения LambdaMediaAds в июне продемонстрировал скачок конверсии, по остальным каналам конверсия показывает более стабильный показатель в динамике.
#
# Удержания по каналу FaceBoom демонстрирует наименьший показатель, что говорит о плохом удержании платящих пользователей. Канал AdNonSense также демонстрирует наименьший показатель удержания. Показатели удержания по данным каналам меньше примерно на 20%, что увеличивает расходы на привлечение новых пользователей по данным каналам.
#
# 5. <b> Рекомендации для отдела маркетинга для повышения эффективности </b>
#
# В ходе выполнения анализа, было выявлено, что отсутствует окупаемость пользователей из США, пользователи из остальных стран демонстрируют окупаемость. Но количество пользователей из США намного превышает количество пользователей из других представленных стран, в связи с этим рекомендуется работать над удержанием платящих пользователей, и привлекать пользователей из прочих стран. Для привлечения стоит использовать рекламные каналы которые показывают более высокую долю платящих пользователей, высокую конверсию и показатель удержания, каналы FaceBoom и TipTop приводят много пользователей, но одновременно с этим отсутствует окупаемость данных каналов, что снижает общую окупаемость по проекту. Стоит более внимательно обратить на каналы: AdNonSense и lambdaMediaAds - данные каналы демонстрирует хорошую прибыльность, окупаемость и хорошую долю платящих пользователей.
# По устройствам пользователей, не смотря на более низкую конверсию, уровень удержания для пользователей устройств PC более высокий, для маркетологов видится более перспективным и дешевым вложением в рекламу будет для пользователей PC. LTV по пользователям PC ниже чем по прочим устройствам, но как видно из графиков, у пользователей PC выше окупаемость, в тоже время и наименьший показатель CAC. Также наблюдается снижение окупаемости в динамике к концу наблюдаемого периода. Ниже всех окупаемость по устройствам iPhone и Mac. Высокие затраты на привлечение пользователей iPhone и MAC приводят к снижению общей окупаемости по проекту. Возможно, стоит поработать над увеличением доли платящих пользователей PC.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Спасибо, очень хороший и подробный общий вывод, которые содержит все промежуточные результаты.
#
# Скорректируй их, пожалуйста, после того как исправишь недочеты.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# поправлено
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>
